# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('datasets/smartphones - smartphones.csv')
df.head(3)
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ?54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ?19,989    81.0
# 2      Samsung Galaxy A14 5G  ?16,499    75.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
#
#                                              display  \
# ...

# %% [markdown]
# ## Data Assessing
#
# ### Quality Issues
#
# 1. **model** - some brands are written diiferently like OPPO in model column `consistency`
# 2. **price** - has unneccesary '₹' `validity`
# 3. **price** - has ',' between numbers `validity`
# 4. **price** - phone Namotel has a price of 99 `accuracy`
# 5. **ratings** - missing values `completeness`
# 6. **processor** - has some incorrect values for some samsung phones(row # -642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002) `validity`
# 7. There is ipod on row 756 `validity`
# 8. **memory** - incorrect values in rows (441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002) `validity`
# 9. **battery** - incorrect values in rows(113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002) `validity`
# 10. **display** - sometimes frequency is not available `completeness`
# 11. **display** - incorrect values in rows(378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002) `validity`
# 12. certain phones are foldable and the info is scattered `validity`
# 13. **camera** - words like Dual, Triple and Quad are used to represent number of cameras and front and rear cameras are separated by '&'
# 14. **camera** - problem with rows (100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016
# ) `validity`
# 15. **card** - sometimes contains info about os and camera `validity`
# 16. **os** - sometimes contains info about bluetooth and fm radio `validity`
# 17. **os** - issue with rows (324,378) `validity`
# 18. **os** - sometimes contains os version name like lollipop `consistency`
# 19. missing values in camera, card and os `completeness`
# 20. datatype  of price and rating is incorrect `validity`
#
#
#
# ### Tidiness Issues
#
# 1. **sim** - can be split into 3 cols has_5g, has_NFC, has_IR_Blaster
# 2. **ram** - can be split into 2 cols RAM and ROM
# 3. **processor** - can be split into processor name, cores and cpu speed.
# 4. **battery** - can be split into battery capacity, fast_charging_available
# 5. **display** - can be split into size, resolution_width, resolution_height and frequency
# 6. **camera** - can be split into front and rear camera
# 7. **card** - can be split into supported, extended_upto

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df.describe()
# Out:
#            rating
# count  879.000000
# mean    78.258248
# std      7.402854
# min     60.000000
# 25%     74.000000
# 50%     80.000000
# 75%     84.000000
# max     89.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df1 = df.copy()

# %%
df['price'] = df['price'].str.replace('₹','').str.replace(',','').str.replace('?','').astype('int')
# Out:
# C:\Users\Rudra\AppData\Local\Temp\ipykernel_15016\425897326.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['price'] = df['price'].str.replace('₹','').str.replace(',','').str.replace('?','').astype('int')

# %%
df = df.reset_index()
df.head(2)
# Out:
#    index                      model  price  rating  \
# 0      0              OnePlus 11 5G  54999    89.0
# 1      1  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# ...

# %%
df['index']  = df['index'] + 2

# %%
df.head(2)
# Out:
#    index                      model  price  rating  \
# 0      2              OnePlus 11 5G  54999    89.0
# 1      3  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# ...

# %%
processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))
ram_rows = set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))
display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))
camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016))

# %%
df[df['index'].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]
# Out:
#       index                              model   price  rating  \
# 98      100                     Vivo X Fold 5G  106990     NaN
# 111     113                    Apple iPhone 12   51999    74.0
# 149     151               Apple iPhone 12 Mini   40999    74.0
# 155     157                    Nokia 2780 Flip    4990     NaN
# 159     161                    Oppo Find N2 5G   94990     NaN
# ...     ...                                ...     ...     ...
# 954     956  Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 988     990                Nokia 5310 Dual Sim    3399     NaN
# 993     995                      Huawei Mate X  169000     NaN
# 1000   1002                    XTouch F40 Flip    1999     NaN
# 1014   1016                      Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df[df['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#       index                   model  price  rating  \
# 640     642          Nokia 105 Plus   1299     NaN
# 645     647         Nokia 2760 Flip   5490     NaN
# 647     649       Motorola Moto A10   1339     NaN
# 657     659           Zanco Tiny T1   2799     NaN
# 665     667            itel it2163S    958     NaN
# 748     750            Nokia 400 4G   3290     NaN
# 757     759            Karbonn KU3i    995     NaN
# 817     819            itel Magic X   2239     NaN
# 882     884  Nokia 5710 XpressAudio   4799     NaN
# 925     927           Nokia 3310 4G   3999     NaN
# 927     929      Samsung Guru E1200   1685     NaN
# 930     932        iKall K88 Pro 4G   2099     NaN
# 1000   1002         XTouch F40 Flip   1999     NaN
#
#                                  sim                   processor  \
# 640                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 645          Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# ...

# %%
df[df['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]['price'].mean()
# Out:
# 2537.6923076923076

# %%
df = df[df['price'] >= 3400]
df.head(3)
# Out:
#    index                      model  price  rating  \
# 0      2              OnePlus 11 5G  54999    89.0
# 1      3  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4      Samsung Galaxy A14 5G  16499    75.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
#
#                                              display  \
# ...

# %%
df[df['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera  \
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0
# ...

# %%
df[df['index'].isin(processor_rows)]
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 857    859             LG Folder 2  11999     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 857       Single Sim, 3G, 4G, Wi-Fi      1 GB RAM, 8 GB inbuilt
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 857                  1470 mAh Battery  2.8 inches, 240 x 320 px Display
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
# ...

# %%
df.drop([645,857,882,925], inplace=True)

# %%
df[df['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
# 582    584                     Nokia 8210 4G    3749     NaN
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 582                                 Dual Sim, 3G, 4G
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 582                                           No Wifi     Unisoc T107
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
# 582                48 MB RAM, 128 MB inbuilt
#
# ...

# %%
df.drop([582], inplace = True)

# %%
df[df['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 376    378               Nokia 2660 Flip    4649     NaN
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 754    756    Apple iPod Touch (7th Gen)   18900     NaN
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df.drop([376,754], inplace=True)

# %%
temp_df = df[df['index'].isin(battery_rows)]

# %%
temp_df
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
x = temp_df.iloc[:,7:].shift(1, axis=1).values
x
# Out:
# array([[None, '6.1 inches, 1170 x 2532 px Display with Large Notch',
#         '12 MP + 12 MP Dual Rear & 12 MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080 x 2340 px Display',
#         '12 MP + 12 MP Dual Rear & 12 MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '6.1 inches, 1170 x 2532 px Display with Large Notch',
#         '12 MP + 12 MP Dual Rear & 12 MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080 x 2340 px Display',
#         '12 MP + 12 MP Dual Rear & 12 MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '4.7 inches, 750 x 1334 px Display',
#         '12 MP Rear & 7 MP Front Camera', 'Memory Card Not Supported',
#         'iOS v15'],
#        [None,
#         '6.06 inches, 1170 x 2532 px, 120 Hz Display with Punch Hole',
#         '50 MP + 12 MP + 12 MP Triple Rear & 12 MP Front Camera',
# ...

# %%
df.loc[temp_df.index,temp_df.columns[7:]] = x

# %%
df[df['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df[df['index'].isin(display_rows)]
# Out:
#      index                         model   price  rating  \
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 448                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# ...

# %%
df[df['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 155     157                           Nokia 2780 Flip    4990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# ...

# %%
df.drop([155,271], inplace=True)

# %%
df[df['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# ...

# %%
temp_df = df[df['index'].isin(camera_rows)]

# %%
temp_df = temp_df[~temp_df['camera'].str.contains('MP')]

# %%
df.loc[temp_df.index, 'camera'] = temp_df['card'].values

# %%
df[df['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# ...

# %%
df['card'].value_counts()
# Out:
# Memory Card Supported, upto 1 TB                                       171
# Memory Card Not Supported                                              123
# Android v12                                                            107
# Memory Card Supported, upto 512 GB                                     105
# Memory Card (Hybrid), upto 1 TB                                         91
# Memory Card Supported                                                   89
# Memory Card Supported, upto 256 GB                                      87
# Android v13                                                             46
# Android v11                                                             41
# Memory Card (Hybrid)                                                    30
# Memory Card (Hybrid), upto 256 GB                                       13
# Android v10                                                             11
# ...

# %%
temp_df = df[df['card'].str.contains('MP')]

# %%
df.loc[temp_df.index, 'card'] = 'Memory Card Not Supported'

# %%
temp_df = df[~df['card'].str.contains('Memory Card')]
temp_df.head()
# Out:
#     index                        model  price  rating  \
# 8      10              Nothing Phone 1  26749    85.0
# 9      11           OnePlus Nord 2T 5G  28999    84.0
# 12     14  Xiaomi Redmi Note 12 Pro 5G  24762    79.0
# 17     19         OPPO Reno 9 Pro Plus  45999    86.0
# 18     20               OnePlus 10R 5G  32999    86.0
#
#                                                sim  \
# 8          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 17         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 18         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                             processor  \
# 8   Snapdragon 778G Plus, Octa Core, 2.5 GHz Proce...
# 9         Dimensity  1300, Octa Core, 3 GHz Processor
# 12       Dimensity 1080, Octa Core, 2.6 GHz Processor
# 17   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# ...

# %%
df.loc[temp_df.index, 'os'] = temp_df['card'].values

# %%
df.loc[temp_df.index, 'card'] = 'Memory Card Not Supported'

# %%
df['card'].value_counts()
# Out:
# Memory Card Not Supported              362
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card Supported, upto 1000 GB      1
# Memory Card (Hybrid), upto 2 TB          1
# Name: card, dtype: int64

# %%
df['os'].value_counts()
# Out:
# Android v12                           394
# Android v11                           274
# Android v13                            91
# Android v10                            69
# Android v9.0 (Pie)                     29
# Android v10.0                          23
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# Android v11.0                           4
# Android v8.0 (Oreo)                     4
# iOS v13                                 4
# iOS v15.0                               3
# Android v6.0 (Marshmallow)              2
# Memory Card (Hybrid), upto 256 GB       2
# Memory Card (Hybrid), upto 2 TB         2
# HarmonyOS v2.0                          2
# Android v5.1.1 (Lollipop)               2
# Harmony v2.0                            2
# EMUI v12                                2
# ...

# %%
df[df['os'].str.contains('Memory Card')]
# Out:
#      index                       model   price  rating  \
# 159    161             Oppo Find N2 5G   94990     NaN
# 306    308     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324            Royole FlexPai 2  109999    87.0
# 365    367            OPPO Find N Flip   89990    88.0
# 392    394           OPPO Find N2 Flip   70990    88.0
# 504    506  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 570    572                  LG Wing 5G   54999    89.0
# 613    615                Oukitel WP21   22990    82.0
# 682    684                LG V60 ThinQ   79990     NaN
# 721    723  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728            Huawei Mate Xs 2  162990    89.0
# 844    846                CAT S22 Flip   14999     NaN
# 894    896         Royole FlexPai 3 5G  149999    87.0
# 993    995               Huawei Mate X  169000     NaN
#
#                                                    sim  \
# 159            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df.loc[temp_df.index, 'os'] = np.nan

# %%
temp_df = df[df['os'] == 'Bluetooth']

# %%
df.loc[temp_df.index, 'os'] = np.nan

# %%
df['os'].value_counts()
# Out:
# Android v12                           287
# Android v11                           233
# Android v10                            58
# Android v13                            45
# Android v9.0 (Pie)                     27
# Android v10.0                          22
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# Memory Card Not Supported               6
# iOS v14                                 6
# Android v8.0 (Oreo)                     4
# Android v11.0                           4
# iOS v15.0                               3
# iOS v13                                 3
# iOS v14.0                               2
# EMUI v12                                2
# Android v6.0 (Marshmallow)              2
# Memory Card Supported, upto 256 GB      2
# Android v5.1.1 (Lollipop)               2
# Memory Card (Hybrid), upto 256 GB       2
# Memory Card (Hybrid), upto 2 TB         2
# ...

# %%
df['display'].value_counts()
# Out:
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole    54
# 6.5 inches, 720 x 1600 px Display with Water Drop Notch        36
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole     25
# 6.52 inches, 720 x 1600 px Display with Water Drop Notch       23
# 6.5 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole      22
#                                                                ..
# 6.92 inches, 1080 x 2460 px, 144 Hz Display                     1
# 6.51 inches, 1080 x 2408 px, 144 Hz Display with Punch Hole     1
# 6.2 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole      1
# 6.43 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole      1
# 6.8 inches, 1080 x 2400 px Display with Punch Hole              1
# Name: display, Length: 347, dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %%
temp_df =  df[df['os']=='Bluetooth']

# %%
df.loc[temp_df.index,'os'] = np.nan

# %%
df.head(3)
# Out:
#    index                      model  price  rating  \
# 0      2              OnePlus 11 5G  54999    89.0
# 1      3  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4      Samsung Galaxy A14 5G  16499    75.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
#
#                                              display  \
# ...

# %%
brand_names = df['model'].str.split(' ').str.get(0)
brand_names
# Out:
# 0         OnePlus
# 1         OnePlus
# 2         Samsung
# 3        Motorola
# 4          Realme
# 5         Samsung
# 6           Apple
# 7          Xiaomi
# 8         Nothing
# 9         OnePlus
# 10         Realme
# 11           Oppo
# 12         Xiaomi
# 13           Vivo
# 14        Samsung
# 15          Apple
# 16           Vivo
# 17           OPPO
# 18        OnePlus
# 19           Vivo
# 20        OnePlus
# 21           Vivo
# 22           Poco
# 23         Xiaomi
# 24           Vivo
# 25        Samsung
# 26        OnePlus
# 27          Apple
# 28           Vivo
# 29        OnePlus
# 30         Realme
# 31           Poco
# 32           Vivo
# 33          Apple
# 34        Samsung
# 35        Samsung
# 36           Oppo
# 37        Samsung
# 38         Xiaomi
# 39           OPPO
# 40        OnePlus
# 41         Xiaomi
# 42       Motorola
# 43         Realme
# 44           Vivo
# 45        Samsung
# 46         Xiaomi
# 47         Realme
# 48           Vivo
# 49        Samsung
# ...

# %%
df.insert(1,'brand', brand_names)

# %%
df.head(3)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  OnePlus              OnePlus 11 5G  54999    89.0
# 1      3  OnePlus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4  Samsung      Samsung Galaxy A14 5G  16499    75.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
#
# ...

# %%
df['brand'] = df['brand'].str.lower()

# %%
df.head(3)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4  samsung      Samsung Galaxy A14 5G  16499    75.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
#
# ...

# %%
has_5g = df['sim'].str.contains('5G')
has_nfc = df['sim'].str.contains('NFC')
has_ir_blaster = df['sim'].str.contains('IR Blaster')

# %%
df.insert(6, 'has_5g', has_5g)
df.insert(7, 'has_nfc', has_nfc)
df.insert(8, 'has_ir_blaster', has_ir_blaster)

# %%
df.head(3)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4  samsung      Samsung Galaxy A14 5G  16499    75.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# ...

# %%
processor_name = df['processor'].str.split(',').str.get(0)

# %%
num_cores = df['processor'].str.split(',').str.get(1)

# %%
processor_speed = df['processor'].str.split(',').str.get(2)

# %%
df.insert(10, 'processor_name', processor_name)
df.insert(11, 'num_cores', num_cores)
df.insert(12, 'processor_speed', processor_speed)

# %%
df.head(3)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4  samsung      Samsung Galaxy A14 5G  16499    75.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
#
#     num_cores     processor_speed                        ram  \
# 0   Octa Core   3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# ...

# %%
df['processor_name'] = df['processor_name'].str.strip()

# %%
temp_df = df[df['processor_name'].str.contains('Core')][['processor_name', 'num_cores', 'processor_speed']].shift(1, axis=1)

# %%
temp_df
# Out:
#      processor_name            num_cores     processor_speed
# 118            None  Octa Core Processor                 NaN
# 143            None            Quad Core   1.4 GHz Processor
# 188            None            Quad Core   1.6 GHz Processor
# 201            None            Octa Core     2 GHz Processor
# 309            None            Octa Core     2 GHz Processor
# 315            None            Quad Core   1.3 GHz Processor
# 496            None  Octa Core Processor                 NaN
# 529            None  Octa Core Processor                 NaN
# 587            None            Octa Core     2 GHz Processor
# 758            None            Quad Core   1.6 GHz Processor
# 778            None            Octa Core   2.2 GHz Processor
# 794            None            Quad Core   1.3 GHz Processor
# 825            None  Octa Core Processor                 NaN
# 826            None  Octa Core Processor                 NaN
# ...

# %%
df.loc[temp_df.index, ['processor_name', 'num_cores', 'processor_speed']] = temp_df.values

# %%
df[df['processor_name'] == '(28 nm)']
# Out:
#      index    brand                    model  price  rating  \
# 856    858  samsung  Samsung Galaxy A01 Core   4999     NaN
#
#                                 sim  has_5g  has_nfc  has_ir_blaster  \
# 856  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
#
#                                  processor processor_name   num_cores  \
# 856  (28 nm), Quad Core, 1.5 GHz Processor        (28 nm)   Quad Core
#
#         processor_speed                      ram           battery  \
# 856   1.5 GHz Processor  1 GB RAM, 16 GB inbuilt  3000 mAh Battery
#
#                                display                         camera  \
# 856  5.3 inches, 720 x 1480 px Display  8 MP Rear & 5 MP Front Camera
#
#                       card           os
# 856  Memory Card Supported  Android v10

# %%
df.loc[856, 'processor_name'] = 'Mediatek MT6739'

# %%
processor_brand = df['processor_name'].str.split(' ').str.get(0).str.lower()

# %%
df.insert(11, 'processor_brand', processor_brand)

# %%
df.head(3)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4  samsung      Samsung Galaxy A14 5G  16499    75.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
#
#   processor_brand   num_cores     processor_speed                        ram  \
# ...

# %%
df['num_cores'] = df['num_cores'].str.strip()

# %%
df['num_cores'].value_counts()
# Out:
# Octa Core              871
# Quad Core               37
# Hexa Core               31
# Octa Core Processor     28
# Hexa Core Processor      8
# Name: num_cores, dtype: int64

# %%
df['num_cores'] = df['num_cores'].str.replace('Octa Core Processor', 'Octa Core').str.replace('Hexa Core Processor', 'Hexa Core')

# %%
df['num_cores'].value_counts()
# Out:
# Octa Core    899
# Hexa Core     39
# Quad Core     37
# Name: num_cores, dtype: int64

# %%
df['processor_speed'] = df['processor_speed'].str.strip().str.split(' ').str.get(0).astype('float')

# %%
df.head(3)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4  samsung      Samsung Galaxy A14 5G  16499    75.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor        Exynos 1330
#
#   processor_brand  num_cores  processor_speed                        ram  \
# ...

# %%
ram_capacity = df['ram'].str.strip().str.split(',').str.get(0).str.findall(r'\b(\d+)\b').str.get(0)

# %%
df.insert(16,'ram_capacity',ram_capacity)

# %%
df.head(3)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4  samsung      Samsung Galaxy A14 5G  16499    75.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... processor_brand  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...      snapdragon
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...      snapdragon
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor  ...          exynos
#
#    num_cores processor_speed                        ram  \
# 0  Octa Core             3.2  12 GB RAM, 256 GB inbuilt
# ...

# %%
internal_memory = df['ram'].str.strip().str.split(',').str.get(1).str.strip().str.findall(r'\b(\d+)\b').str.get(0)

# %%
df.insert(17,'internal_memory',internal_memory)

# %%
df.head(3)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4  samsung      Samsung Galaxy A14 5G  16499    75.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ...  num_cores  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...  Octa Core
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...  Octa Core
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor  ...  Octa Core
#
#   processor_speed                        ram  \
# 0             3.2  12 GB RAM, 256 GB inbuilt
# 1             2.2   6 GB RAM, 128 GB inbuilt
# ...

# %%
df['ram_capacity'] = df['ram_capacity'].astype('float')

# %%
df[df['ram_capacity'] > 18]
# Out:
#      index   brand                             model   price  rating  \
# 439    441   apple            Apple iPhone SE 3 2022   43900     NaN
# 483    485  huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 486    488   nokia                     Nokia 8000 4G    6899     NaN
# 627    629   nokia                      Nokia 225 4G    3589     NaN
# 762    764   apple                 Apple iPhone SE 4   49990    60.0
#
#                                                  sim  has_5g  has_nfc  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster   False     True
# 486                          Dual Sim, 3G, 4G, Wi-Fi   False    False
# 627                          Dual Sim, 3G, 4G, VoLTE   False    False
# 762          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
#
#      has_ir_blaster                                         processor  ...  \
# ...

# %%
df.loc[[439,762], ['ram_capacity','internal_memory']] = [[4, '64'], [4, '64']]

# %%
df.loc[[483], ['ram_capacity','internal_memory']] = [[12, '512']]

# %%
df.loc[[483], ['ram_capacity','internal_memory']]
# Out:
#      ram_capacity internal_memory
# 483          12.0             512

# %%
df[df['ram_capacity'] > 18]
# Out:
#      index  brand          model  price  rating                      sim  \
# 486    488  nokia  Nokia 8000 4G   6899     NaN  Dual Sim, 3G, 4G, Wi-Fi
# 627    629  nokia   Nokia 225 4G   3589     NaN  Dual Sim, 3G, 4G, VoLTE
#
#      has_5g  has_nfc  has_ir_blaster  \
# 486   False    False           False
# 627   False    False           False
#
#                                          processor  ...  num_cores  \
# 486  Snapdragon  210, Quad Core, 1.1 GHz Processor  ...  Quad Core
# 627                                    Unisoc T117  ...        NaN
#
#     processor_speed                        ram           battery ram_capacity  \
# 486             1.1   512 MB RAM, 4 GB inbuilt  1500 mAh Battery        512.0
# 627             NaN  64 MB RAM, 128 MB inbuilt  1150 mAh Battery         64.0
#
#     internal_memory                           display              camera  \
# 486               4  2.8 inches, 240 x 320 px Display    2 MP Rear Camera
# ...

# %%
df.drop([486,627], inplace=True)

# %%
df['ram_capacity'].value_counts()
# Out:
# 8.0     339
# 6.0     234
# 4.0     217
# 12.0     86
# 3.0      54
# 2.0      32
# 16.0      9
# 1.0       7
# 18.0      2
# Name: ram_capacity, dtype: int64

# %%
df['internal_memory'] = df['internal_memory'].astype('float')

# %%
temp_df = df[df['internal_memory'] == 1]

# %%
df.loc[temp_df.index, 'internal_memory'] = 1024

# %%
df['internal_memory'].value_counts()
# Out:
# 128.0     523
# 64.0      193
# 256.0     157
# 32.0       67
# 512.0      22
# 16.0       12
# 1024.0      5
# 8.0         1
# Name: internal_memory, dtype: int64

# %%
battery_capacity = df['battery'].str.strip().str.split(' ').str.get(0).astype('float')

# %%
df.columns
# Out:
# Index(['index', 'brand', 'model', 'price', 'rating', 'sim', 'has_5g',
#        'has_nfc', 'has_ir_blaster', 'processor', 'processor_name',
#        'processor_brand', 'num_cores', 'processor_speed', 'ram', 'battery',
#        'ram_capacity', 'internal_memory', 'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
df.insert(16, 'battery_capacity', battery_capacity)

# %%
df.head(2)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... processor_speed  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...             3.2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...             2.2
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt  5000 mAh Battery with 100W Fast Charging
# 1   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
#
#    battery_capacity ram_capacity internal_memory  \
# 0            5000.0         12.0           256.0
# ...

# %%
fast_charging = df['battery'].str.strip().str.split('with').str.get(1).str.strip().str.findall(r'\d{2,3}')

# %%
df.insert(17, 'fast_charging', fast_charging)

# %%
#df.drop(columns='fast_charging', inplace=True)

# %%
df.head(2)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ...  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt  5000 mAh Battery with 100W Fast Charging
# 1   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
#
#   battery_capacity  fast_charging ram_capacity internal_memory  \
# 0           5000.0            100         12.0           256.0
# ...

# %%
df['fast_charging'].value_counts()
# Out:
# [33]     152
# [18]     128
# []        68
# [67]      65
# [25]      53
# [120]     46
# [15]      43
# [80]      42
# [66]      37
# [10]      33
# [30]      32
# [65]      30
# [44]      23
# [45]      17
# [20]      10
# [68]       8
# [100]      7
# [150]      7
# [125]      6
# [40]       5
# [22]       5
# [60]       4
# [55]       3
# [50]       2
# [210]      2
# [21]       2
# [180]      1
# [200]      1
# [240]      1
# [19]       1
# [135]      1
# [165]      1
# [27]       1
# Name: fast_charging, dtype: int64

# %%
def fast_charging_extractor(item):

  if type(item) == list:
    if len(item) == 1:
      return item[0]
    else:
      return 0
  else:
    return -1

# %%
df['fast_charging'] = df['fast_charging'].apply(fast_charging_extractor).astype(int)

# %%
df.head(2)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ...  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt  5000 mAh Battery with 100W Fast Charging
# 1   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
#
#   battery_capacity  fast_charging ram_capacity internal_memory  \
# 0           5000.0            100         12.0           256.0
# ...

# %%
df['fast_charging'].value_counts()
# Out:
#  33     152
# -1      143
#  18     128
#  0       68
#  67      65
#  25      53
#  120     46
#  15      43
#  80      42
#  66      37
#  10      33
#  30      32
#  65      30
#  44      23
#  45      17
#  20      10
#  68       8
#  100      7
#  150      7
#  125      6
#  40       5
#  22       5
#  60       4
#  55       3
#  50       2
#  210      2
#  21       2
#  180      1
#  200      1
#  240      1
#  19       1
#  135      1
#  165      1
#  27       1
# Name: fast_charging, dtype: int64

# %%
screen_size = df['display'].str.strip().str.split(',').str.get(0).str.strip().str.split(' ').str.get(0).astype('float')

# %%
#df.drop(columns='screen_size',inplace=True)

# %%
df.insert(21,'screen_size', screen_size)

# %%
df.head(2)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ...  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...
#
#                                     battery battery_capacity fast_charging  \
# 0  5000 mAh Battery with 100W Fast Charging           5000.0           100
# 1   5000 mAh Battery with 33W Fast Charging           5000.0            33
#
#    ram_capacity internal_memory  \
# 0          12.0           256.0
# 1           6.0           128.0
#
# ...

# %%
resolution = df['display'].str.strip().str.split(',').str.get(1).str.strip().str.split('px').str.get(0)

# %%
df.insert(22,'resolution', resolution)

# %%
refresh_rate = df['display'].str.strip().str.split(',').str.get(2).str.strip().str.split('Hz').str.get(0).astype('float')

# %%
df.insert(23,'refresh_rate', refresh_rate)

# %%
df.head(2)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... fast_charging  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...           100
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...            33
#
#   ram_capacity internal_memory  \
# 0         12.0           256.0
# 1          6.0           128.0
#
#                                              display screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...        6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...        6.59
#
#      resolution  refresh_rate  \
# ...

# %%
#df['camera'].value_counts()

# %%
def camera_extractor(text):

    if 'Quad' in text:
        return '4'
    elif 'Triple' in text:
        return '3'
    elif 'Dual' in text:
        return '2'
    elif 'Missing' in text:
        return 'Missing'
    else:
        return '1'

# %%
num_rear_cam = df['camera'].str.strip().str.split('&').str.get(0).apply(camera_extractor)

# %%
df.insert(25, 'num_rear_cameras', num_rear_cam)

# %%
df.head(2)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... ram_capacity  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...         12.0
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...          6.0
#
#   internal_memory                                            display  \
# 0           256.0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1           128.0  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
#
#    screen_size    resolution refresh_rate  \
# 0         6.70  1440 x 3216         120.0
# ...

# %%
num_front_cam = df['camera'].str.strip().str.split('&').str.get(1).str.strip().fillna('Missing').apply(camera_extractor)

# %%
df.insert(26, 'num_front_cameras', num_front_cam)

# %%
df.head(2)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... internal_memory  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...           256.0
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...           128.0
#
#                                              display screen_size  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...        6.70
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...        6.59
#
#      resolution refresh_rate  \
# 0  1440 x 3216         120.0
# 1  1080 x 2412         120.0
#
# ...

# %%
df[df['num_front_cameras'] == 'Missing']
# Out:
#       index   brand                model   price  rating  \
# 69       71    oppo     Oppo Find N Fold   99990     NaN
# 462     464  xiaomi  Xiaomi Mi Mix Alpha  199990     NaN
# 993     995  huawei        Huawei Mate X  169000     NaN
# 1012   1014    itel            itel A23s    4787     NaN
#
#                                                     sim  has_5g  has_nfc  \
# 69              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 462                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 1012                            Dual Sim, 3G, 4G, Wi-Fi   False    False
#
#       has_ir_blaster                                          processor  ...  \
# 69             False  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor  ...
# 462            False     Snapdragon 855+, Octa Core, 2.96 GHz Processor  ...
# 993             True          Kirin  990, Octa Core, 2.86 GHz Processor  ...
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.loc[69,'camera'] == '50 MP'
# Out:
# False

# %%
temp_df = df[df['camera'] == 'Foldable Display, Dual Display']

# %%
df.loc[temp_df.index, 'camera'] = '50 MP'

# %%
df['primary_camera_rear'] = df1['camera'].str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df.head(2)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
#
#                                     battery  battery_capacity  fast_charging  \
# ...

# %%
df['primary_camera_front'] = df['camera'].str.split('&').str.get(1).str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df[df['card'] == 'Memory Card (Hybrid)']
# Out:
#      index     brand                                      model  price  \
# 25      27   samsung                   Samsung Galaxy S20 FE 5G  31239
# 80      82  motorola                       Motorola Moto G72 4G  15999
# 147    149   samsung                      Samsung Galaxy M34 5G  16999
# 151    153  motorola                          Motorola Moto G52  11999
# 178    180      vivo                                Vivo Y75 5G  21990
# 204    206  motorola        Motorola Moto G52 (6GB RAM + 128GB)  12999
# 248    250  motorola                          Motorola Moto G73  25999
# 254    256    xiaomi                Xiaomi Redmi Note 11 Pro 5G  17990
# 281    283      vivo                               Vivo V23e 5G  21994
# 305    307    xiaomi                    Xiaomi Mi 11 Lite NE 5G  21890
# 441    443      poco                                Poco X3 Pro  19650
# 470    472    xiaomi  Xiaomi Mi 11 Lite NE 5G (8GB RAM + 128GB)  22999
# ...

# %%
df.loc[temp_df.index, 'card'] = 'Not Specified'

# %%
df['extended_memory'] = df['card'].apply(lambda x:'0' if 'Not' in x else x.split('upto')).str.get(-1).str.strip().str.replace('Memory Card Supported','Not Specified')

# %%
df.head(2)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
#
#                                     battery  battery_capacity  fast_charging  \
# ...

# %%
df['os'].value_counts()
# Out:
# Android v12                           287
# Android v11                           233
# Android v10                            58
# Android v13                            45
# Android v9.0 (Pie)                     27
# Android v10.0                          22
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# Memory Card Not Supported               6
# iOS v14                                 6
# Android v8.0 (Oreo)                     4
# Android v11.0                           4
# iOS v15.0                               3
# iOS v13                                 3
# iOS v14.0                               2
# EMUI v12                                2
# Android v6.0 (Marshmallow)              2
# Memory Card Supported, upto 256 GB      2
# Android v5.1.1 (Lollipop)               2
# Memory Card (Hybrid), upto 256 GB       2
# Memory Card (Hybrid), upto 2 TB         2
# ...

# %%
df['os'].str.contains('Memory Card').isnull().sum()
# Out:
# 213

# %%
temp_df = df[df['os'].isnull()]

# %%
df.loc[temp_df.index, 'os'] = 'Not Specified'

# %%
df['os'].value_counts()
# Out:
# Android v12                           286
# Android v11                           233
# Not Specified                         214
# Android v10                            58
# Android v13                            45
# Android v9.0 (Pie)                     27
# Android v10.0                          22
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# Android v8.0 (Oreo)                     4
# Android v11.0                           4
# iOS v15.0                               3
# iOS v13                                 3
# Memory Card (Hybrid), upto 2 TB         2
# Memory Card (Hybrid), upto 256 GB       2
# Android v5.1.1 (Lollipop)               2
# Harmony v2.0                            2
# Memory Card Supported, upto 256 GB      2
# Android v6.0 (Marshmallow)              2
# ...

# %%
def os_extractor(text):

  if 'Android' in text:
    return 'android'
  elif 'iOS' in text:
    return 'ios'
  elif 'Not Specified':
    return text
  elif 'Harmony' in text or 'Hongmeng' in text or 'EMUI' in text:
    return 'other'

# %%
df['os'] = df['os'].apply(os_extractor)

# %%
df.head(2)
# Out:
#    index    brand                      model  price  rating  \
# 0      2  oneplus              OnePlus 11 5G  54999    89.0
# 1      3  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  Snapdragon 8 Gen2
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor     Snapdragon 695
#
#   processor_brand  num_cores  processor_speed                        ram  \
# 0      snapdragon  Octa Core              3.2  12 GB RAM, 256 GB inbuilt
# 1      snapdragon  Octa Core              2.2   6 GB RAM, 128 GB inbuilt
#
#                                     battery  battery_capacity  fast_charging  \
# ...

# %%
export_df = df.drop(columns=['index','sim','processor','ram','battery','display','camera','card'])

# %%
export_df.head(2)
# Out:
#      brand                      model  price  rating  has_5g  has_nfc  \
# 0  oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1  oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
#
#    has_ir_blaster     processor_name processor_brand  num_cores  \
# 0           False  Snapdragon 8 Gen2      snapdragon  Octa Core
# 1           False     Snapdragon 695      snapdragon  Octa Core
#
#    processor_speed  battery_capacity  fast_charging  ram_capacity  \
# 0              3.2            5000.0            100          12.0
# 1              2.2            5000.0             33           6.0
#
#    internal_memory  screen_size    resolution  refresh_rate  num_rear_cameras  \
# 0            256.0         6.70  1440 x 3216          120.0                 3
# 1            128.0         6.59  1080 x 2412          120.0                 3
#
#   num_front_cameras       os primary_camera_rear primary_camera_front  \
# ...

# %%
export_df.to_csv('smartphone_cleaned_v2.csv',index=False)
